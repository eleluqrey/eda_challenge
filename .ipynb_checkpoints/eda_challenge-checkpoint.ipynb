# %%
import pandas as pd
from ipywidgets import interact
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pylab as plt
import seaborn as ns

# %%
# Explora los distintos csvs

# %%
# 1º Explore diamonds_city.csv

# %%
diamonds_city = pd.read_csv('csv_tables/diamonds_city.csv')
diamonds_city
# Out:
#                                               city_id           city
# 0   0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...      Amsterdam
# 1   1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...         Zurich
# 2   2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...      Las Vegas
# 3   5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...  New York City
# 4   5dd272b4f316b776a7b8e3d0894b37e1e42be3d5d3b204...          Paris
# 5   68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...       Tel Aviv
# 6   6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...          Dubai
# 7   89c7286890f7347ab235234e74d406596a127ae3679042...       Kimberly
# 8   ba04d229e496b8383a4df91f5e77c194a95cf1a069b0b2...          Surat
# 9   ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...        Antwerp
# 10  e9c722cbefc2f055ae60b4e2cbe73a2d99537eab0c37f3...         Madrid
# 11  ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...         London
# 12  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...     Luxembourg

# %%
diamonds_clarity = pd.read_csv('csv_tables/diamonds_clarity.csv')
diamonds_clarity
# Out:
#                                           clarity_id clarity
# 0  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1  3f9db06236e9719b61c826b612b882fa702ec81574e44c...    VVS2
# 2  66686ae1f0c9c400ba32dc600a34ff0aa173395bcbc2d8...    VVS1
# 3  7020fd7aaf1656dea5c0c0c3d4bb5a28ebf6243fba95d3...      IF
# 4  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# 5  c2818bc4e5ec4ae4a357a0df6fed73652e169ec676f7d4...      I1
# 6  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 7  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2

# %%
diamonds_color = pd.read_csv('csv_tables/diamonds_color.csv')
diamonds_color
# Out:
#                                             color_id color
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1  3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...     D
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 3  6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 4  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...     I
# 5  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...     E
# 6  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F

# %%
diamonds_cut = pd.read_csv('csv_tables/diamonds_cut.csv')
diamonds_cut
# Out:
#                                               cut_id        cut
# 0  388655e25e91872329272fc10128ef5354b3b19a05d7e8...  Very Good
# 1  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...      Ideal
# 2  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...       Good
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...    Premium
# 4  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...       Fair

# %%
diamonds_dimensions = pd.read_csv('csv_tables/diamonds_dimensions.csv')
diamonds_dimensions
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z
# 0      6.79  4.25
# ...

# %%
diamonds_properties = pd.read_csv('csv_tables/diamonds_properties.csv')
diamonds_properties
# Out:
#                                                 index_id  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...                                                  ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...
#
#                                                   cut_id  \
# 0      de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1      388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 2      f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# ...

# %%
diamonds_transactional = pd.read_csv('csv_tables/diamonds_transactional.csv')
diamonds_transactional
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   0.32
# ...

# %%
# ANALIZA EL DATA FRAME COMPLETO

# 1º DATA FRAME COMPLETO
# Hacemos merge para unir todos los data frames de par en par uniendo por la columna que tengan en común.

diamonds_df = diamonds_color.merge(diamonds_properties,on = 'color_id')
diamonds_df
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                                 index_id  \
# 0      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 1      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...

# %%
diamonds_df = diamonds_df.merge(diamonds_cut,on = 'cut_id')
diamonds_df
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                                 index_id  \
# 0      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 1      a4e00d7e6aa82111575438c5e5d3e63269d4c475c718b2...
# ...

# %%
diamonds_df = diamonds_df.merge(diamonds_clarity,on = 'clarity_id')
diamonds_df
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                                 index_id  \
# 0      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 1      f1916530dae6514fd8ba7c17eadab5ba6739cbd9190b7f...
# ...

# %%
diamonds_df = diamonds_df.merge(diamonds_transactional,on = 'index_id')
diamonds_df
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                                 index_id  \
# 0      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 1      f1916530dae6514fd8ba7c17eadab5ba6739cbd9190b7f...
# ...

# %%
diamonds_df = diamonds_df.merge(diamonds_city,on = 'city_id')
diamonds_df
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 3      6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...     E
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                                 index_id  \
# 0      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 1      4ed6af94d2babfb73aae073691a59e8e6a1beb6bfaf77b...
# ...

# %%
diamonds_df = diamonds_df.merge(diamonds_dimensions,on = 'index_id')
diamonds_df
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 3      6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...     E
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                                 index_id  \
# 0      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 1      4ed6af94d2babfb73aae073691a59e8e6a1beb6bfaf77b...
# ...

# %%
# 2º Una vez tenemos el data frame completo con toda la información vamos a analizarlo:

# %%
# Exploring numeric features
@interact(Feature=list(diamonds_df.select_dtypes(include=['float64','int64']).columns))

def histogram(Feature):
    fig = px.histogram(diamonds_df[Feature], marginal = 'box')
    fig.show()
# Out:
# interactive(children=(Dropdown(description='Feature', options=('price', 'carat'), value='price'), Output()), _…

# %%
fig = px.histogram(diamonds_df['depth'], marginal = 'box')
fig.show()
# Out:
# <div>                            <div id="4794add7-af01-46df-bfcd-2e26a6e0f134" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4794add7-af01-46df-bfcd-2e26a6e0f134")) {                    Plotly.newPlot(                        "4794add7-af01-46df-bfcd-2e26a6e0f134",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=depth<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"depth","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"depth","offsetgroup":"depth","orientation":"v","showlegend":true,"x":[65.5,58.0,71.8,66.6,62.1,62.2,61.3,61.9,61.5,62.2,62.0,61.2,62.4,60.9,61.6,61.8,62.0,62.7,62.1,61.9,62.4,61.7,61.9,62.6,62.1,61.8,62.0,62.1,61.4,60.6,61.8,62.7,62.6,61.1,61.0,62.6,62.3,62.1,61.6,62.0
# ...

# %%
@interact(Feature=list(diamonds_df.select_dtypes(include=['object']).columns[1:]))

def histogram(Feature):
    fig = px.bar(diamonds_df[Feature])
    fig.show()
# Out:
# interactive(children=(Dropdown(description='Feature', options=('color', 'index_id', 'cut_id', 'clarity_id', 'c…

# %%
corr_df = diamonds_df.select_dtypes(include = ['int64','float64']).corr()
px.imshow(corr_df, text_auto = True)
# Out:
# <div>                            <div id="3187a32f-53e2-49a4-a4f7-db4f70bb4719" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3187a32f-53e2-49a4-a4f7-db4f70bb4719")) {                    Plotly.newPlot(                        "3187a32f-53e2-49a4-a4f7-db4f70bb4719",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["price","carat","depth","table","x","y","z"],"y":["price","carat","depth","table","x","y","z"],"z":[[1.0,0.9219351745876515,-0.014864269575237555,0.13011052361893935,0.885847944376775,0.8661632281914142,0.8745004883098132],[0.9219351745876515,1.0,0.026527985115818303,0.18339210950687235,0.9756879014791294,0.9516672314701836,0.9675700811437342],[-0.014864269575237555,0.026527985115818303,1.0,-0.2931135
# ...

# %%
corr_df
# Out:
#           price     carat     depth     table         x         y         z
# price  1.000000  0.921935 -0.014864  0.130111  0.885848  0.866163  0.874500
# carat  0.921935  1.000000  0.026528  0.183392  0.975688  0.951667  0.967570
# depth -0.014864  0.026528  1.000000 -0.293114 -0.026348 -0.030966  0.094655
# table  0.130111  0.183392 -0.293114  1.000000  0.196059  0.184673  0.155189
# x      0.885848  0.975688 -0.026348  0.196059  1.000000  0.973712  0.984876
# y      0.866163  0.951667 -0.030966  0.184673  0.973712  1.000000  0.964828
# z      0.874500  0.967570  0.094655  0.155189  0.984876  0.964828  1.000000

# %%
# Mapa de calor
plt.figure(figsize=(10, 8))
ns.heatmap(corr_df, annot=True, cmap = "crest")
# Out:
# <Axes: >
